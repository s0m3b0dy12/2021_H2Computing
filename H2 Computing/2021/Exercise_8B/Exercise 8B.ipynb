# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Q1 - Task 2.2

def InitialiseAnimals():
    
    
    MyAnimal = [''] * 33
    index = 0
    
    file = open("ANIMALS.txt",'r')
    
    for line in file:
        line = line.strip().split("=")
        MyAnimal[index] = line[1].strip('"')
        index+=1
        
    file.close()
    print(MyAnimal)
        
    return MyAnimal

def BinarySearch(A,key):
    high = len(A)-1
    low = 0
    found = False
    
    mid = (high + low)//2
    
    while (high != low) and not found:
        if key > A[mid]:
            low = (high + low)//2 + 1
            mid = (high + low)//2
        elif key < A[mid]:
            high = (high+low)//2 - 1
            mid = (high + low)//2
        else:
            print(key,mid)
            found = True
            
    if key == A[mid]:
        found=True
            
    if found:
        return f"Key is located in index {(high + low)//2}"
    else:
        return "Key is not located in array"
    
def main():
    key = 'cat' 
    MyAnimal = InitialiseAnimals()
    print(BinarySearch(MyAnimal,key))
    
main()
# Out:
# ['aardvark', 'ant', 'antelope', 'bat', 'boa constrictor', 'camel', 'cat', 'cheetah', 'dog', 'donkey', 'duck', 'elephant', 'frog', 'giraffe', 'hare', 'horse', 'iguana', 'jackass', 'jaguar', 'leopard', 'lion', 'llama', 'mouse', 'ostrich', 'panther', 'parrot', 'rhinoceros', 'seahorse', 'seal', 'spider', 'turtle', 'whale', 'zebra']
# Key is located in index 6

# %%
# Q1 - Task 2.3
def InitialiseAnimals(file):
    MyAnimal = []
    animals = open(file, "r")
    for line in animals:
        line = line.strip().split("=")
        MyAnimal.append(line[1].strip('"'))
        
    return MyAnimal


def binarySearch(array,key):
    low = 0
    high = len(array)-1
    call = 0
    while low != high:
        call+=1
        mid = (low + high)//2
        if key == array[mid]:
            return mid
        elif key < array[mid]:
            high = mid-1
        else:
            low = mid+1
    return -1

def output(animals,key):
    print("Key is:", key)
    if binarySearch(animals,key) == -1:
        print("Key is not in array.")
    else:
        print("Key is in index", binarySearch(animals,key))
        
    return 0

def main():
    animals = InitialiseAnimals("ANIMALS.txt")
    key = 'dodo'
    output(animals,key)
    key = 'horse'
    output(animals,key)   

    
# Issue: some items in the array do not have their index output
main()
# Out:
# Key is: dodo
# Key is not in array.
# Key is: horse
# Key is not in array.

# %% [markdown]
# 2. GCE 2016 P1 Q2
# ![image.png](attachment:image.png)

# %%
# Q2 - Task 2.1

def InitialiseTable():
    Max = 20
    table = [''] * Max
    
    return table

def store(filename,table):
    
    file = open(filename,'r')
    
    for line in file:
        line = int(line.strip())
        index = line%(len(table))
        table[index] = line
    return table

def main():
    filename = "KEYS1.txt"
    print(store(filename,InitialiseTable()))
    
main()
# Out:
# ['', '', '', '', 4, '', '', 7, '', '', '', '', '', '', '', '', '', 17, '', 19]

# %%
# Q2 - Task 2.2

def store(filename,table):
    file = open(filename,'r')
    
    for line in file:
        line = int(line.strip())
        index = line%(len(table))
        
        if table[index] == '':
            table[index] = line
        else:
            while table[index] != '':
                index+=1
                if index >= len(table):
                    index = 0
                
            table[index] = line  
    return table
    

def main():
    filename = "KEYS2.txt"
    print(solveCollision(filename,InitialiseTable()))
    
main()
# Out:
# [57, 77, '', '', 4, '', '', 7, '', '', '', '', '', '', '', '', '', 17, 37, 19]

# %%
# Q2 - Task 2.3

def store(filename,table):
    file = open(filename,'r')
    
    for line in file:
        line = int(line.strip())
        index = line%(len(table))
        
        if table[index] == '':
            table[index] = line
        else:
            while table[index] != '':
                index+=1
                if index >= len(table):
                    index = 0
                
            table[index] = line  
    return table

def search(A,key):
    index = -1
    for i in range(0,len(A)-1):
        if key == A[i]:
            index = i
            
    if index == -1:
        return "The key is not found in the array"
    else:
        return f"The key is found in index {index} of the array"

def main():
    filename = "KEYS2.txt"
    array = InitialiseTable()
    store(filename,array)
    
    key = 37
    print(search(array,key))
    key = 77
    print(search(array,key))
    key = 97
    print(search(array,key))
    
main()
# Out:
# The key is found in index 18 of the array
# The key is found in index 1 of the array
# The key is not found in the array

# %% [markdown]
# 3. SP P1 Q2
# ![image.png](attachment:image.png)

# %%
# Q3 - Task 2.1

# %%
# Q3 - Task 2.2
